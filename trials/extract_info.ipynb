# %% [markdown]
# # Import OpenCV

# %%
import cv2

# %% [markdown]
# # Dimension and Channel

# %%
img = cv2.imread('cat.png')
height, width, channels = img.shape

# %% [markdown]
# # Display DataType

# %%
print(img.dtype)
# Out:
# uint8
