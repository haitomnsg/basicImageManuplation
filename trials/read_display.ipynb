# %% [markdown]
# # Importing OpenCV

# %%
import cv2

# %%
cv2.imread('cat.png', cv2.IMREAD_COLOR_RGB)
# Out:
# array([[[ 40,  52,   1],
#         [ 40,  49,   1],
#         [ 41,  51,   1],
#         ...,
#         [ 25,  41,   0],
#         [ 27,  43,   2],
#         [ 25,  42,   1]],
#
#        [[ 40,  52,   2],
#         [ 38,  49,   1],
#         [ 40,  50,   1],
#         ...,
#         [ 28,  45,   5],
#         [ 32,  49,   5],
#         [ 23,  40,   0]],
#
#        [[ 39,  51,   0],
#         [ 41,  52,   1],
#         [ 41,  50,   0],
#         ...,
#         [ 35,  51,  13],
#         [ 28,  44,   3],
#         [ 24,  40,   0]],
#
#        ...,
#
#        [[197, 214, 136],
#         [200, 217, 140],
#         [197, 213, 136],
#         ...,
#         [241, 184, 145],
#         [216, 151, 108],
#         [197, 131,  85]],
#
#        [[197, 214, 136],
#         [199, 216, 141],
#         [198, 214, 138],
#         ...,
#         [246, 188, 144],
#         [227, 168, 127],
#         [201, 136,  92]],
#
#        [[198, 214, 137],
#         [198, 214, 139],
#         [196, 213, 135],
#         ...,
#         [241, 189, 144],
#         [222, 163, 122],
#         [229, 171, 133]]], dtype=uint8)

# %% [markdown]
# # Importing Matplotlib

# %%
import matplotlib.image as mpimage
import matplotlib.pyplot as plt

# %%
img = mpimage.imread('cat.png')

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# # Sci-Kit Import

# %%
from skimage import io

# %%
image = io.imread('cat.png')

io.imshow(image)
io.show()
# Out:
# /tmp/ipykernel_2774/3233763990.py:3: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(image)
# /tmp/ipykernel_2774/3233763990.py:4: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %% [markdown]
# Image IO Import

# %%
import imageio.v3 as iio

# %%
image = iio.imread('cat.png')
print(image.shape)
# Out:
# (500, 500, 4)
